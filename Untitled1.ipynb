// %%
fun main(args: Array<String>) {

            //val and var
            val c = "World"
            var a: String = "Hello"

            //c = "India";
            a = "beta"
            println("Hello Abhishek !!!")
            println("Count = ${count + 12}")
            println("Hello $name, Welcome to kotlin world")

            println("Sum is : ${add(5, 6)}")
            println("The output of any func is ${anyValue()}")

            //pair and triple
            var myPair: Pair<String, Int>
            var myName = Pair("Rahul", true)
            println("${myName.first},${myName.second}")
            //myPair = Pair("")


        }
// Out:
// Line_0.jupyter.kts (1:10 - 14) Parameter 'args' is never used
// Line_0.jupyter.kts (4:17 - 18) Variable 'c' is never used
// Line_0.jupyter.kts (5:17 - 18) Variable 'a' is assigned but never accessed
// Line_0.jupyter.kts (8:13 - 16) The value '"beta"' assigned to 'var a: String defined in Line_0_jupyter.main' is never used
// Line_0.jupyter.kts (10:32 - 37) Function invocation 'count(...)' expected
// Line_0.jupyter.kts (10:32 - 37) Unresolved reference. None of the following candidates is applicable because of receiver type mismatch:
// public inline fun <T> Array<out TypeVariable(T)>.count(): Int defined in kotlin.collections
// public inline fun <T> Array<out TypeVariable(T)>.count(predicate: (TypeVariable(T)) -> Boolean): Int defined in kotlin.collections
// public inline fun BooleanArray.count(): Int defined in kotlin.collections
// public inline fun BooleanArray.count(predicate: (Boolean) -> Boolean): Int defined in kotlin.collections
// ...

// %%
var count: Int = 10
var name: String = "Rahul"

// %%
print(count)
// Out:
// 10
