// %% [markdown]
// * #### Generics are features that allow you to create type-agnostic classes, functions, interfaces while  ensuirng type safety at compile time.
// * #### These are compile time feature and don’t retain type information at runtime
